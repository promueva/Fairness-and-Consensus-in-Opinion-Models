# %%
import networkx as nx

# %%
# DeGroot
complete = nx.DiGraph(nx.complete_graph(5))
nx.draw(complete)

# %%
# our model

ours = nx.fast_gnp_random_graph(5, 0.3, directed=True)
while not nx.is_strongly_connected(ours):
    ours = nx.fast_gnp_random_graph(5, 0.3, directed=True)
nx.draw(ours)

# %%
from PushDeGrootGraph import *

G = PushDeGrootGraph(5, ops=[0.2, 0.8])
G.draw()

# %%
G.make_call((0,1))
G.draw()

# %%
G.make_call((0,1))
G.draw()

# %%
G.make_call((0,1))
G.draw()
